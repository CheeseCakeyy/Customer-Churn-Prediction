# %% [markdown]
# ## Importing data:

# %%
import pandas as pd

train_path = '/kaggle/input/competitions/playground-series-s6e3/train.csv'
test_path = '/kaggle/input/competitions/playground-series-s6e3/test.csv'

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

print("Train shape:", train_df.shape) 
display(train_df.head(3))
print("Test shape:", test_df.shape)
display(test_df.head(3))
# Out:
# Train shape: (594194, 21)
#    id gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0   Male              0     Yes        Yes      29          Yes
# 1   1   Male              0     Yes        Yes      58          Yes
# 2   2   Male              0     Yes         No      58          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL            Yes  ...              Yes
# 1            No             DSL            Yes  ...               No
# 2           Yes     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
#
#              PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0             Mailed check           60.1       1653.85     No
# 1  Credit card (automatic)           69.5       3778.20     No
# 2         Electronic check          100.4       5841.35     No
#
# [3 rows x 21 columns]
# Test shape: (254655, 20)
#        id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  594194  Female              0     Yes         No      72          Yes
# 1  594195  Female              0     Yes         No      71          Yes
# 2  594196    Male              0      No         No      12          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                  Yes                  Yes
# 1            No              No  No internet service  No internet service
# 2            No             DSL                  Yes                  Yes
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                  Yes                  Yes                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                  Yes        Two year              Yes
# 1  No internet service        Two year               No
# 2                   No  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0           Electronic check          115.55       8061.50
# 1  Bank transfer (automatic)           19.80       1336.50
# 2  Bank transfer (automatic)           55.55        633.55

# %%
target = 'Churn'

cat_cols = ['gender','Partner', 'Dependents', 'SeniorCitizen',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',] 

num_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
train_df[target] = train_df[target].map({'No': 0, 'Yes': 1})

# %% [markdown]
# ## Feature Engineering:
# We'll include **Digit Decomposition** from the most iteration and add **TargetEncoding** newly...

# %%
combined_df = pd.concat([train_df,test_df], axis=0, ignore_index=True)

# %% [markdown]
# #### Digit Decomposition:

# %%
import numpy as np

digit_cols = []

for col in num_cols:
    max_val = combined_df[col].abs().max()

    #conditional 1:
    if max_val == 0:
        digit_count = 1
    else:
      digit_count = int(np.log10(max_val)) + 1  

    for i in range(digit_count):
        new_col = f"{col}_digit_pos_{i+1}"

        combined_df[new_col] = (combined_df[col] // (10**i)) % 10
        combined_df[new_col] = combined_df[new_col].astype(int)

        digit_cols.append(new_col)

    #conditional 2:
    if combined_df[col].dtype == 'float64':
        max_dec_count = 2

        if (combined_df[col] % 1 != 0).any():
            for i in range(1, max_dec_count + 1):
                new_col = f"{col}_digit_dec_{i}"
                
                combined_df[new_col] = (combined_df[col] * (10**i)).round().astype(int) % 10
                
                digit_cols.append(new_col)

# %%
print('Newly created digit_cols are as follows: \n',digit_cols)
# Out:
# Newly created digit_cols are as follows:
#  ['tenure_digit_pos_1', 'tenure_digit_pos_2', 'MonthlyCharges_digit_pos_1', 'MonthlyCharges_digit_pos_2', 'MonthlyCharges_digit_pos_3', 'MonthlyCharges_digit_dec_1', 'MonthlyCharges_digit_dec_2', 'TotalCharges_digit_pos_1', 'TotalCharges_digit_pos_2', 'TotalCharges_digit_pos_3', 'TotalCharges_digit_pos_4', 'TotalCharges_digit_dec_1', 'TotalCharges_digit_dec_2']

# %% [markdown]
# #### N-gram features:

# %%
cols_for_bigram = ['Contract', 'InternetService', 'PaymentMethod', 'OnlineSecurity', 'TechSupport', 'PaperlessBilling']

cols_for_trigram = ['Contract', 'InternetService', 'PaymentMethod', 'OnlineSecurity']

# %%
from itertools import combinations

BiGram_cols = []
TriGram_cols = []

#Bi-grams
for c1,c2 in combinations(cols_for_bigram, 2):
    new_col = f"bi_{c1}_{c2}"
    combined_df[new_col] = (combined_df[c1].astype(str) + "_" + combined_df[c2].astype(str)).astype('object')
    BiGram_cols.append(new_col)

print(f"created a total of {len(BiGram_cols)} bi-gram features")

#Tri-grams
for c1,c2,c3 in combinations(cols_for_trigram, 3):
    new_col = f'tri_{c1}_{c2}_{c3}'
    combined_df[new_col] = (combined_df[c1].astype(str) + "_" + combined_df[c2].astype(str) + "_" + combined_df[c3].astype(str)).astype('object')
    TriGram_cols.append(new_col)

print(f"created a total of {len(TriGram_cols)} tri-gram features")
# Out:
# created a total of 15 bi-gram features
# created a total of 4 tri-gram features

# %%
NGram_features = BiGram_cols + TriGram_cols
print(f"A total of {len(NGram_features)} were created")
# Out:
# A total of 19 were created

# %%
train_df = combined_df.iloc[: len(train_df)].reset_index(drop=True)
test_df  = combined_df.iloc[len(train_df) :].reset_index(drop=True)

# %% [markdown]
# #### TargetEncoder:
# We'll be using the custom column transformer we made during Heart-Disease-Prediction competition for target encoding

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class TargetEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols):
        self.cat_cols = cat_cols
        self.mean_maps = {}
        self.global_mean = None
        
    def fit(self, X, y):
        X = X.copy()
        self.global_mean = y.mean()

        for col in self.cat_cols:
            self.mean_maps[col] = y.groupby(X[col]).mean()
        return self

    def transform(self, X):
        X = X.copy()
        
        for col in self.cat_cols:
            X[col + "_TE"] = X[col].map(self.mean_maps[col])
            X[col + "_TE"] = X[col + "_TE"].fillna(self.global_mean) #handling unseen values
        return X

# %%
from sklearn.pipeline import Pipeline

TE = TargetEncoder(cat_cols=NGram_features) #TargetEncoder instance

train_TE = TE.fit_transform(train_df[NGram_features],train_df[target])
test_TE = TE.transform(test_df[NGram_features])

#dropping caat_cols from train_TE and test_TE
train_TE = train_TE.drop(NGram_features, axis=1)
test_TE = test_TE.drop(NGram_features, axis=1)

# %%
TE_cols = train_TE.columns.tolist()
print('Newly created TE_cols are as follows: \n', TE_cols)
# Out:
# Newly created TE_cols are as follows:
#  ['bi_Contract_InternetService_TE', 'bi_Contract_PaymentMethod_TE', 'bi_Contract_OnlineSecurity_TE', 'bi_Contract_TechSupport_TE', 'bi_Contract_PaperlessBilling_TE', 'bi_InternetService_PaymentMethod_TE', 'bi_InternetService_OnlineSecurity_TE', 'bi_InternetService_TechSupport_TE', 'bi_InternetService_PaperlessBilling_TE', 'bi_PaymentMethod_OnlineSecurity_TE', 'bi_PaymentMethod_TechSupport_TE', 'bi_PaymentMethod_PaperlessBilling_TE', 'bi_OnlineSecurity_TechSupport_TE', 'bi_OnlineSecurity_PaperlessBilling_TE', 'bi_TechSupport_PaperlessBilling_TE', 'tri_Contract_InternetService_PaymentMethod_TE', 'tri_Contract_InternetService_OnlineSecurity_TE', 'tri_Contract_PaymentMethod_OnlineSecurity_TE', 'tri_InternetService_PaymentMethod_OnlineSecurity_TE']

# %% [markdown]
# ## Feature Importance:

# %%
features = cat_cols + num_cols + TE_cols + digit_cols

# %%
X = pd.concat([train_df,train_TE], axis=1)
X_test = pd.concat([test_df,test_TE], axis=1)

# %%
# categorical_features = cat_cols + NGram_features

# for df in [X, X_test]:
#     for col in categorical_features:
#         df[col] = df[col].astype(str).astype('category')

# %%
for df in [X, X_test]:
    for col in cat_cols:
        df[col] = df[col].astype(str).astype('category')

# %%
#These hyperparameters were chosen by Optuna
best_xgb_params = {'n_estimators': 2500,
                   'learning_rate': 0.021343076630791043,
                   'max_depth': 6,
                   'min_child_weight': 7,
                   'gamma': 0.861751498622332, 
                   'subsample': 0.8551145690799331,
                   'colsample_bytree': 0.6623034984700539,
                   'reg_alpha': 0.019334069196449158,
                   'reg_lambda': 6.572714277172166}

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    **best_xgb_params,
    random_state= 42,
    eval_metric= "logloss",
    tree_method= "hist",   
    verbosity= 0,
    device= 'cuda',
    enable_categorical= True
)

model.fit(X[features],X[target])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6623034984700539, device='cuda',
#               early_stopping_rounds=None, enable_categorical=True,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.861751498622332, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.021343076630791043,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=2500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model, max_num_features=20)
plt.show()

# %%
y_pred = model.predict_proba(X_test[features])[:,1]

# %%
submission = pd.DataFrame({
    'id': test_df['id'],
    target: y_pred 
})

submission.to_csv('submission2.csv', index= False)
